# %% [markdown]
# ### imports

# %%
from data_config import *
from visualize import *

# %% [markdown]
# ### read data

# %%
END_OF_PATH = '_clean.csv'

# %%
data_cancel_culture = pd.read_csv('data/' + TOPICS[0] + END_OF_PATH)
data_feminism = pd.read_csv('data/' + TOPICS[1] + END_OF_PATH)
data_lgbtq_plus = pd.read_csv('data/' + TOPICS[2] + END_OF_PATH)
data_ageism = pd.read_csv('data/' + TOPICS[3] + END_OF_PATH)
data_lookism = pd.read_csv('data/' + TOPICS[4] + END_OF_PATH)

# %% [markdown]
# ### look on examples of clean data

# %% [markdown]
# #### cancel culture

# %%
make_examples(data_cancel_culture, 3)
# Out:
# Эээ, за это не кэнселят
#
# "от кэнселлинга страдают и друзья и близкие того кого кэнселят" ок сиди в тюрьме вместе с друзьями и близкими я разрешаю
#
# И тут мне интересно, что вы скажите о культуры отмены, например, доя Мохова? Или норм его вообще пригласить ведущим в прайм-тайм на федеральные каналы?

# %% [markdown]
# #### feminism

# %%
make_examples(data_feminism, 3)
# Out:
# БЛЯЯЯ мне щас мама сказала сделать опару я спросила у сестры че такое опара она сказала это феминитив к слову опарыш
#
# если зайти в профили к таким мальчикам, то там полный набор обсирания вообще всех без повода, сексизм расизм гомофобия и три тонны оскорблений ну, такие люди я полагаю уже мертвы морально и не жили никогда
#
# Печально, когда в погоне за наградами режиссеры снимают фильмы, бездумно и бессмысленно запихивая туда лгбт, феминизм и тд, и получается говно, и из-за этого тема лгбт и феминизма в таких фильмах выглядит как бельмо даже для самих лгбт и феминисток

# %% [markdown]
# #### LGBTQ+

# %%
make_examples(data_lgbtq_plus, 3)
# Out:
# Муж гей? Нет, блядь, жена лесбиянка
#
# эх все бы знали что стояло за этим лесби-имиджем
#
# что сказать парню если вы встречаетесь он тебя любит а ты осознала что ты лесбиянка..............

# %% [markdown]
# #### ageism

# %%
make_examples(data_ageism, 3)
# Out:
# Фарида, вы же в курсе, что Макрон состоит в браке с женщиной, которая на 1 (один) год моложе его вчерашнего собеседника? И да, это эйджизм называется. Мне кажется, есть железная логика в рифме "фарида-тупая пиХда".
#
# Уууу эйджизм))
#
# проблема вашего эйджизма в том что вы ну базово юзаете тупорылые слова "малолетка" и тд не входите в положение ребёнка, вы +/- в их возрасте были ТАКИМИ ЖЕ  вы все были школьниками и школьницами вам всем было от 0 до 12  не хотите эйджизма? помогайте детям ОСОСЗНАТЬ ошибку

# %% [markdown]
# #### lookism

# %%
make_examples(data_lookism, 3)
# Out:
# ещё раз: так может выражаться надо так, чтобы вырванная из треда фраза не выглядела как "ты виноват в фэтфобии своей худобой" :')
#
# Одна из разновидностей объективизации, если подумать
#
# те, кто видят в этом твите оскорбление НАС, сами и порождают дискриминацию по внешности  другой вопрос - использование фото другого человека, неважно кого. но в сети куча мемов с лицами разных людей. и че скажете, что вы так же на них реагируете

# %% [markdown]
# ### look on count of tweets for each month

# %%
visualize_year_month(data_cancel_culture, 'cancel culture')
visualize_year_month(data_feminism, 'feminism')
visualize_year_month(data_lgbtq_plus, 'LGBTQ+')
visualize_year_month(data_ageism, 'ageism')
visualize_year_month(data_lookism, 'lookism')
